# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
clinic_data = pd.read_csv("Resources/clinicaltrial_data.csv")
mice_data = pd.read_csv("Resources/mouse_drug_data.csv")

# %%
mice_data.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
clinic_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
vol = clinic_data["Tumor Volume (mm3)"]
max_vol = max(vol)
min_vol = min(vol)
print(max_vol, min_vol) # ---> 78.56701362140001
id = clinic_data["Mouse ID"]
# Out:
# 78.56701362140001 22.0501262735

# %%
m_df = pd.DataFrame(mice_data)

# %%
c_df = pd.DataFrame(clinic_data)
#c_df
print(c_df)
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# 5        h246          0           45.000000                 0
# 6        p189          0           45.000000                 0
# 7        n923          0           45.000000                 0
# 8        q119          0           45.000000                 0
# 9        f993          0           45.000000                 0
# 10       z234          0           45.000000                 0
# 11       b559          0           45.000000                 0
# 12       y260          0           45.000000                 0
# 13       x930          0           45.000000                 0
# ...

# %%
x_limit = 100

# %%
#xlimit = 100
x_axis = np.arange(0, x_limit, .1)

# %%
data = [c_df for value in x_axis]

# %%
# plt.scatter(x_axis, clinic_data, marker="o", facecolors="red", edgecolors="black",
#             s=x_axis, alpha=0.75)
plt.scatter(id, vol, marker=".", facecolors="red", edgecolors="black", s=x_axis, alpha=1, linewidths=.001)
plt.show
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#plt.xlim(100,200)

# %%
m_df.merge(self, right, how='left', left_on="mouse_id" right_on="Mouse ID"
# Out:
#   File "<ipython-input-55-4ad845dcd7c7>", line 1
#     m_df.merge(self, right, how='left', left_on="mouse_id" right_on="Mouse ID"
#                                                                   ^
# SyntaxError: invalid syntax
